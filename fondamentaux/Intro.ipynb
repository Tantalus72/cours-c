# %% [markdown]
# # Introduction au Langage de Programmation C
#
# ## Sommaire
#
# 1. [**Installation et configuration**](./jupyther/01_setup.ipynb)
#    - Choix d'un compilateur (GCC, Clang, etc)
#    - Configuration d'un environnement de développement (IDE ou terminal)
#
# 2. [**Structure de base d'un programme C**](./jupyther/02_base.ipynb)
#    - La fonction `main`
#    - Inclusion des bibliothèques standard
#    - Bibliothèques utiles
#
#
# 3. [**Les types de données et variables**](./jupyther/03_variables.ipynb)
#    - Types primitifs (int, char, float, etc.)
#    - Déclaration et initialisation
#
# 4. [**Opérateurs et expressions**](./jupyther/04_op.ipynb)
#    - Opérateurs arithmétiques, logiques et relationnels
#    - Opérateurs d'affectation et d'incrémentation
#
# 5. [**Les structures de contrôle**](./jupyther/05_structure.ipynb)
#    - Les conditions (`if`, `else`, `switch`)
#    - Les boucles (`for`, `while`, `do-while`)
#
# 6. [**Les fonctions**](./jupyther/06_fonction.ipynb)
#    - Définition et appel de fonctions
#    - Passage de paramètres
#    - Retour de valeurs
#
# 7. [**Les tableaux et pointeurs**](./jupyther/07_tableau.ipynb)
#    - Déclaration et manipulation des tableaux
#    - Introduction aux pointeurs
#    - Relations entre pointeurs et tableaux
#
# 8. [**Gestion de la mémoire**](./jupyther/08_memoire.ipynb)
#    - Allocation dynamique (`malloc`, `free`)
#    - Gestion des fuites mémoire
#
# 9. [**Pointeur**](./jupyther/09_pointeur.ipynb)
#     - Utilisation dans les tableaux, fonction etc
#     - Explication du pourquoi
#
# 10. [**Modularité**](./jupyther/10_module.ipynb)
#     - Organisation du code en fichiers multiples
#     - Utilisation des en-têtes (`.h`)
#
# 11. [**POO**](./jupyther/11_POO.ipynb)
#    - Déclaration des classes, methodes et
#    - Encapsulation
#
# 99. [**Complement**](./jupyther/99_complement.ipynb)
